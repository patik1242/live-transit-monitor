# %%
from pyspark.sql import functions as F
b = spark.read.table("dbr_dev.live_transit_monitor.gps_data")
b.select(F.count("*").alias("rows"), F.max("event_time").alias("max_evt")).show(truncate=False)

# %%
# %sql
DROP TABLE dbr_dev.live_transit_monitor.gps_positions_silver

# %%
spark.range(1).count()
